# %%
from sklearn.model_selection import train_test_split 
import numpy as np
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score,confusion_matrix
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn import tree

# %%
data = pd.DataFrame({
    'idade': [5,10,3,8,1,15],
    'hist_manu': [2,0,3,1,3,0],
    'falhas': [0,3,0,2,0,5],
    'auto': [2,0,1,2,1,0],
    'classif': ['segura','não segura','segura','não segura','segura','não segura']
})

# %%
x=np.array(data['idade']) # pega a coluna tempo do dataframe
y=np.array(data['classif']) # pega a coluna de classificação do dataframe
x_treino,x_teste,y_treino,y_teste = train_test_split(x.reshape(-1,1),y.reshape(-1,1),
                                                     test_size=0.2,random_state=42)
model = DecisionTreeClassifier()
model.fit(x_treino,y_treino)
prev = model.predict(x_teste)
acurracy = accuracy_score(y_teste,prev)
precisao = precision_score(y_teste,prev,pos_label='segura')
matrix = confusion_matrix(y_teste,prev)
print(f"Acurácia: {acurracy}")
print(f"Matrix: {matrix}")
print(f"Precisão: {precisao}")
fig = plt.figure(figsize=(10,8))
tree.plot_tree(model,feature_names=x.tolist(),class_names=y.tolist(),filled=True)
plt.show()
# Out:
# Acurácia: 1.0
# Matrix: [[1 0]
#  [0 1]]
# Precisão: 1.0

# %%
sns.heatmap(matrix,annot=True,fmt='d',cmap='Reds',annot_kws={"size": 16},cbar=False,xticklabels=['Segura','Não segura'],yticklabels=['Segura','Não segura'])
plt.xlabel('Previsão')
plt.ylabel('Verdadeiro')
plt.title('Matriz de Confusão - Classificação das máquinas')
plt.show()

# %%
x_teste
# Out:
# array([[ 5],
#        [10]], dtype=int64)

# %%
matrix
# Out:
# array([[1, 0],
#        [0, 1]], dtype=int64)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix

# Supondo que 'data' já esteja definido
x = np.array(data['idade'])  # Pega a coluna idade do DataFrame
y = np.array(data['classif'])  # Pega a coluna de classificação do DataFrame

# Divisão em treino e teste
x_treino, x_teste, y_treino, y_teste = train_test_split(x.reshape(-1, 1), y, 
                                                            test_size=0.2, random_state=42)

# Treinamento do modelo
model = DecisionTreeClassifier()
model.fit(x_treino, y_treino)

# Previsões e métricas
prev = model.predict(x_teste)
acurracy = accuracy_score(y_teste, prev)
precisao = precision_score(y_teste, prev, pos_label='segura')
matrix = confusion_matrix(y_teste, prev)

print(f"Acurácia: {acurracy}")
print(f"Matriz: \n{matrix}")
print(f"Precisão: {precisao}")

# Exibir a árvore de decisão
fig = plt.figure(figsize=(10, 8))
plot_tree(model, feature_names=['idade'], class_names=np.unique(y), filled=True)
plt.title('Árvore de Decisão')
plt.show()

# Exibir a matriz de confusão
plt.figure(figsize=(8, 6))
sns.heatmap(matrix, annot=True, fmt='d', cmap='Reds', cbar=False,
            xticklabels=np.unique(y), yticklabels=np.unique(y),
            linewidths=0.5, linecolor='black', annot_kws={"size": 16})  # Aumentar o tamanho da fonte

plt.xlabel('Previsão')
plt.ylabel('Verdadeiro')
plt.title('Matriz de Confusão - Classificação')
plt.xticks(rotation=45)  # Rotacionar rótulos do eixo X
plt.yticks(rotation=0)   # Manter rótulos do eixo Y na horizontal
plt.tight_layout()       # Ajustar layout para evitar cortes
plt.show()
# Out:
# Acurácia: 1.0
# Matriz:
# [[1 0]
#  [0 1]]
# Precisão: 1.0
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[7], line 32
#      30 # Exibir a árvore de decisão
#      31 fig = plt.figure(figsize=(10, 8))
# ---> 32 plot_tree(model, feature_names=['idade'], class_names=np.unique(y), filled=True)
#      33 plt.title('Árvore de Decisão')
#      34 plt.show()
#
# File c:\Users\dsadm\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:201, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     198 to_ignore += ["self", "cls"]
#     199 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 201 validate_parameter_constraints(
#     202     parameter_constraints, params, caller_name=func.__qualname__
#     203 )
#     205 try:
#     206     with config_context(
# ...

# %%
matrix_normalized = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]
sns.heatmap(matrix_normalized, annot=True, fmt='.2f', cmap='Reds')
plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Exemplo de valores (substitua pela sua matriz real)
# matrix = confusion_matrix(y_teste, prev)
matrix = np.array([[50, 2], [1, 47]])  # Exemplo de matriz

# Visualizar a matriz de confusão
plt.figure(figsize=(10, 8))  # Aumente o tamanho da figura
sns.heatmap(matrix, annot=True, fmt='d', cmap='Reds', 
            annot_kws={"size": 20}, cbar=False, 
            xticklabels=['Segura', 'Não segura'], 
            yticklabels=['Segura', 'Não segura'],
            linewidths=0.5, linecolor='black')  # Linhas de separação

plt.xlabel('Previsão')
plt.ylabel('Verdadeiro')
plt.title('Matriz de Confusão - Classificação das Máquinas')
plt.xticks(rotation=45)  # Rotacionar rótulos do eixo X
plt.yticks(rotation=0)   # Manter rótulos do eixo Y na horizontal
plt.tight_layout()       # Ajustar layout para evitar cortes
plt.show()
